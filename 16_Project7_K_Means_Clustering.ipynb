# %% [markdown]
# # Projeto de K Means Clustering

# %% [markdown]
# Nesse projeto usaremos o KMC para agrupar as universidades em dois grupos: privadas e públicas.
#
# **Obs:** é importante observar que o conjunto de dados já possui um rótulo indicando se é pública ou privada mas não usaremos esses dados pois o KMeans é um algoritmo de aprendizado não supervisionado.
#
# Ao usar o algoritmo de KMeans em situações reais, você não possuirá rótulos. Nesse caso, usaremos rótulos para tentar ter uma ideia do quão bem o algoritmo foi executado.
#
# Usaremos um quadro de dados com 777 observações sobre as 18 variáveis a seguir:
# * Private: Um fator com Não e Sim indicando universidade privada ou pública.
# * Apps: Número de inscrições recebidas.
# * Accept: Quantidade de inscrições aceitas.
# * Enroll: Número de estudantes matriculados.
# * Top10perc: Percentual de novos estudantes vindo do grupo de 10% melhores do segundo grau.
# * Top25perc: Percentual de novos estudantes vindo do grupo de 25% melhores do segundo grau.
# * F.Undegrad: Número de alunos de graduação em tempo integral.
# * P.Undergrad: Número de alunos de graduação em tempo parcial.
# * Outstate: Alunos de fora do estado.
# * Room.Board: Custos da sala.
# * Books: Custos de livros estimados.
# * Personal: Estimativa de gastos por pessoa.
# * PhD: Percentual de PhDs na universidade.
# * Terminal: Percentual da faculdade com graduação.
# * S.F.Ratio: Taxa estudantes/faculdade.
# * perc.alumni: Percentual dos ex-alunos que doam.
# * Expend: Despesas da instituição por aluno.
# * Grad.Rate: Taxa de graduação.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('College_Data', index_col=0)

# %%
df.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Private      777 non-null    object
#  1   Apps         777 non-null    int64
#  2   Accept       777 non-null    int64
#  3   Enroll       777 non-null    int64
#  4   Top10perc    777 non-null    int64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     777 non-null    int64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    float64
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
# ...

# %%
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ## Análise exploratória de dados

# %%
# Taxa de graduação da universidade vs Custo por sala

plt.figure(figsize=(12,8))
sns.set_style('whitegrid')
sns.scatterplot(x='Room.Board', y="Grad.Rate", data=df, hue='Private', s=100, palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='Room.Board', ylabel='Grad.Rate'>

# %% [markdown]
# Podemos verificas 2 pontos importantes do gráfico acima:
# * No geral, universidades particulares possuem um custo por sala maior e uma taxa de graduação maior também

# %%
# Número de alunos de graduação em tempo integral vs alunos de fora do estado

plt.figure(figsize=(12,8))
sns.set_style('whitegrid')
sns.scatterplot(x='Outstate', y="F.Undergrad", data=df, hue='Private', s=100, palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='Outstate', ylabel='F.Undergrad'>

# %% [markdown]
# * Como podemos perceber, o número de alunos de fora do estado é maior em universidades particulares
# * Alunos de universidades públicas passam mais tempo integral na universidade

# %%
sns.set_style('darkgrid')
g = sns.FacetGrid(df, hue='Private', palette='coolwarm', height=7)
g = g.map(plt.hist, 'Outstate', bins=20, alpha=.5)

# %%
sns.set_style('darkgrid')
g = sns.FacetGrid(df, hue='Private', palette='coolwarm', height=7)
g = g.map(plt.hist, 'Grad.Rate', bins=20, alpha=.5)

# %% [markdown]
# * A taxa de graduação das universidades particulares é maior que das universidades públicas
# * Note também que tem uma universidade com taxa de graduação maior que 100%. Um erro de coleta. Vamos verificar.

# %%
df[df['Grad.Rate'] > 100]
# Out:
#                   Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# Cazenovia College     Yes  3847    3433     527          9         35
#
#                    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# Cazenovia College         1010           12      9384        4840    600
#
#                    Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# Cazenovia College       500   22        47       14.3           20    7697
#
#                    Grad.Rate
# Cazenovia College        118

# %% [markdown]
# ## Criação dos clusters "K Means"

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=2)

kmeans.fit(df.drop('Private', axis=1))
# Out:
# KMeans(n_clusters=2)

# %%
# Centróides dos clusters
kmeans.cluster_centers_
# Out:
# array([[1.81323468e+03, 1.28716592e+03, 4.91044843e+02, 2.53094170e+01,
#         5.34708520e+01, 2.18854858e+03, 5.95458894e+02, 1.03957085e+04,
#         4.31136472e+03, 5.41982063e+02, 1.28033632e+03, 7.04424514e+01,
#         7.78251121e+01, 1.40997010e+01, 2.31748879e+01, 8.93204634e+03,
#         6.51195815e+01],
#        [1.03631389e+04, 6.55089815e+03, 2.56972222e+03, 4.14907407e+01,
#         7.02037037e+01, 1.30619352e+04, 2.46486111e+03, 1.07191759e+04,
#         4.64347222e+03, 5.95212963e+02, 1.71420370e+03, 8.63981481e+01,
#         9.13333333e+01, 1.40277778e+01, 2.00740741e+01, 1.41705000e+04,
#         6.75925926e+01]])

# %% [markdown]
# ## Avaliação

# %%
df['Private'] = df['Private'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(df['Private'], kmeans.labels_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.21      0.65      0.31       212
#            1       0.31      0.06      0.10       565
#
#     accuracy                           0.22       777
#    macro avg       0.26      0.36      0.21       777
# weighted avg       0.29      0.22      0.16       777

# %%
print(confusion_matrix(df['Private'], kmeans.labels_))
# Out:
# [[138  74]
#  [531  34]]
